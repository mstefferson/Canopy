# %%
import pickle
import numpy as np

# %%
trees_coords = pickle.load(open('../tree_coords.pkl', 'rb'))
tree_dict = pickle.load(open('../tree_dict.pkl', 'rb'))

# %%
len(tree_dict['trees_global'])
# Out:
# 549

# %%
trees_coords
# Out:
# [(21978, 22398),
#  (21978, 22551),
#  (21984, 22168),
#  (21984, 22170),
#  (22000, 22657),
#  (22001, 22678),
#  (22001, 22680),
#  (22002, 22692),
#  (22005, 21811),
#  (22007, 22392),
#  (22025, 22391),
#  (22034, 22355),
#  (22043, 22377),
#  (22063, 22382),
#  (22081, 22379),
#  (22084, 22693),
#  (22090, 22377),
#  (22097, 22571),
#  (22104, 22375),
#  (22109, 21821),
#  (22112, 22341),
#  (22113, 22274),
#  (22115, 22275),
#  (22115, 22277),
#  (22115, 22351),
#  (22125, 21819),
#  (22128, 22437),
#  (22128, 22439),
#  (22141, 22445),
#  (22141, 22447),
#  (22141, 22449),
#  (22141, 22451),
#  (22150, 22490),
#  (22151, 22486),
#  (22151, 22520),
#  (22153, 22362),
#  (22154, 21814),
#  (22167, 21811),
#  (22167, 22498),
#  (22167, 22500),
#  (22179, 22653),
#  (22179, 22655),
#  (22187, 21808),
#  (22195, 22576),
#  (22195, 22578),
#  (22196, 22581),
#  (22198, 22354),
#  (22209, 22245),
#  (22219, 22228),
#  (22220, 22574),
#  (22229, 22229),
#  (22231, 22228),
# ...

# %%
a = np.array([np.array([1,2,3]), np.array([4,5,6])])

# %%
a.ravel()
